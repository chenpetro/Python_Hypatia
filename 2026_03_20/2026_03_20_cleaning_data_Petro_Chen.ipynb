# %% [markdown]
# <a href="https://colab.research.google.com/github/chenpetro/04_08_22_Lesson8_Semester2_Web_1_01_2/blob/main/2026_03_20_cleaning_data_Petro_Chen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("batch1.dat", sep=" ")
print(df)
# Out:
#      1   1:15596.162100   2:1.868245   3:2.371604   4:2.803678   5:7.512213  \
# 0    1   1:26402.070400   2:2.532401   3:5.411209   4:6.509906   5:7.658469
# 1    1   1:42103.582000   2:3.454189   3:8.198175  4:10.508439  5:11.611003
# 2    1   1:42825.988300   2:3.451192  3:12.113940  4:16.266853  5:39.910056
# 3    1   1:58151.175700   2:4.194839  3:11.455096  4:15.715298  5:17.654915
# 4    1   1:79872.130800   2:5.553595  3:18.690482  4:27.191770  5:28.636972
# ..  ..              ...          ...          ...          ...          ...
# 439  6   1:74805.051800   2:6.707129  3:15.446750  4:19.415134  5:20.782742
# 440  6   1:92035.515600   2:7.775487  3:21.173590  4:27.620422  5:29.159638
# 441  6  1:107898.233400   2:8.994761  3:25.131079  4:33.771374  5:37.121172
# 442  6  1:119795.035200   2:9.582606  3:28.944716  4:39.290350  5:41.062943
# 443  6  1:140782.297800  2:10.975342  3:35.524802  4:59.584134  5:50.208230
#
# ...

# %%
df
# Out:
#      1   1:15596.162100   2:1.868245   3:2.371604   4:2.803678   5:7.512213  \
# 0    1   1:26402.070400   2:2.532401   3:5.411209   4:6.509906   5:7.658469
# 1    1   1:42103.582000   2:3.454189   3:8.198175  4:10.508439  5:11.611003
# 2    1   1:42825.988300   2:3.451192  3:12.113940  4:16.266853  5:39.910056
# 3    1   1:58151.175700   2:4.194839  3:11.455096  4:15.715298  5:17.654915
# 4    1   1:79872.130800   2:5.553595  3:18.690482  4:27.191770  5:28.636972
# ..  ..              ...          ...          ...          ...          ...
# 439  6   1:74805.051800   2:6.707129  3:15.446750  4:19.415134  5:20.782742
# 440  6   1:92035.515600   2:7.775487  3:21.173590  4:27.620422  5:29.159638
# 441  6  1:107898.233400   2:8.994761  3:25.131079  4:33.771374  5:37.121172
# 442  6  1:119795.035200   2:9.582606  3:28.944716  4:39.290350  5:41.062943
# 443  6  1:140782.297800  2:10.975342  3:35.524802  4:59.584134  5:50.208230
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Columns: 129 entries, 1 to 128:-2.654529
# dtypes: int64(1), object(128)
# memory usage: 447.6+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
df.iloc[0]
# Out:
# 1                              1
# 1:15596.162100    1:26402.070400
# 2:1.868245            2:2.532401
# 3:2.371604            3:5.411209
# 4:2.803678            4:6.509906
#                        ...
# 124:0.728443        124:1.628050
# 125:1.445783        125:1.951172
# 126:-0.545079      126:-0.889333
# 127:-0.902241      127:-1.323505
# 128:-2.654529      128:-1.749225
# Name: 0, Length: 129, dtype: object

# %%
df.iloc[0:0]
# Out:
# Empty DataFrame
# ...

# %%
with open("batch1.dat", "r") as f:
    print("First 5 lines:")
    for i, line in enumerate(f):
        if i >= 5:
            break
        print(repr(line.strip()))
# Out:
# First 5 lines:
# ...

# %%
def parse_batch1_dat(path):
    rows = []
    gas_id = None

    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            # Gas‑label line: single digit 1–6
            if len(line) == 1 and line in "123456":
                gas_id = int(line)
                continue

            # Otherwise this line is a feature row: 1:... 2:...
            features = {"gas": gas_id}  # attach gas label from previous line
            for part in line.split():
                if ":" not in part:
                    continue  # ignore malformed parts
                idx, val = part.split(":", 1)
                features[int(idx)] = float(val)

            rows.append(features)

    return pd.DataFrame(rows)

df = parse_batch1_dat("batch1.dat")
print(df.shape)
print(df.head())
# Out:
# (445, 129)
#     gas           1         2          3          4          5          6  \
# 0  None  15596.1621  1.868245   2.371604   2.803678   7.512213  -2.739388
# 1  None  26402.0704  2.532401   5.411209   6.509906   7.658469  -4.722217
# 2  None  42103.5820  3.454189   8.198175  10.508439  11.611003  -7.668313
# 3  None  42825.9883  3.451192  12.113940  16.266853  39.910056  -7.849409
# 4  None  58151.1757  4.194839  11.455096  15.715298  17.654915 -11.083364
#
#            7          8           9  ...       119       120        121  \
# 0  -3.344671  -4.847512  15326.6914  ... -1.071137 -3.037772  3037.0390
# 1  -5.817651  -7.518333  23855.7812  ... -1.530519 -1.994993  4176.4453
# 2  -9.478675 -12.230939  37562.3008  ... -2.384784 -2.867291  5914.6685
# 3  -9.689894 -11.921704  38379.0664  ... -2.607199 -3.058086  6147.4744
# 4 -13.580692 -16.407848  51975.5899  ... -3.594763 -4.181920  8158.6449
#
#         122       123       124       125       126       127       128
# ...
